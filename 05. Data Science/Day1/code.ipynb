# %% [markdown]
# # Day 1 of Data Science Projects

# %%
print("test")
# Out:
# test

# %%
for i in range(5):
    print(f"Iteration {i}")
# Out:
# Iteration 0
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4

# %% [markdown]
# ## This is the first day of our data science projects. This day is just for introduction and getting familiar with the tools we will be using. We will be using Jupyter Notebooks for our projects, which is a great tool for data science.
